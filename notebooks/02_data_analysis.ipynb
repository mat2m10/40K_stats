# %%
import json
from pathlib import Path

# %%
tyranids = json.loads(Path("../data/raw_scraped_waha/tyranids.json").read_text())

# %%
nr = 3
tyranids[nr]['name'], tyranids[nr]['id']
# Out:
# ('Hyperadapted Raveners', 'hyperadapted_raveners')

# %%
tyranids[nr]
# Out:
# {'name': 'Hyperadapted Raveners',
#  'id': 'hyperadapted_raveners',
#  'stats': {'M': '10"', 'T': '5', 'Sv': '4+', 'W': '6', 'Ld': '7+', 'OC': '1'},
#  'weapons': [{'name': 'Venom bolt assault ignores cover torrent',
#    'range': '12"',
#    'A': 'D6+3',
#    'BS_WS': 'N/A',
#    'S': '6',
#    'AP': '-1',
#    'D': '1',
#    'abilities': ''},
#   {'name': 'Prime claws and talons anti-monster 5+ anti-vehicle 5+ twin-linked',
#    'range': 'Melee',
#    'A': '6',
#    'BS_WS': '3+',
#    'S': '5',
#    'AP': '-2',
#    'D': '2',
#    'abilities': ''},
#   {'name': 'Ravener heavy claws and talons anti-monster 5+ anti-vehicle 5+ twin-linked',
#    'range': 'Melee',
#    'A': '3',
#    'BS_WS': '3+',
#    'S': '5',
#    'AP': '-2',
#    'D': '2',
#    'abilities': ''}],
#  'abilities': [{'name': 'Alpha Invader',
# ...

# %%
import os
for i in range(len(tyranids)):
    name = tyranids[i]['id']
    os.makedirs(f"../data/miniatures/tyranids/{name}",exist_ok=True)
