# %% [markdown]
# # Wahapedia 40k Scraper
# Run cells top to bottom. Each cell is self-contained for easy debugging.

# %%
import asyncio, aiohttp, json, re
import nest_asyncio
from pathlib import Path
from bs4 import BeautifulSoup

nest_asyncio.apply()

FACTIONS = {
    "space-marines":        "Space Marines",
    "necrons":              "Necrons",
    "chaos-space-marines":  "Chaos Space Marines",
    "tyranids":             "Tyranids",
    "orks":                 "Orks",
    "aeldari":              "Aeldari",
    "t-au-empire":          "T'au Empire",
    "astra-militarum":      "Astra Militarum",
    "death-guard":          "Death Guard",
    "thousand-sons":        "Thousand Sons",
    "world-eaters":         "World Eaters",
    "genestealer-cults":    "Genestealer Cults",
    "drukhari":             "Drukhari",
    "adeptus-mechanicus":   "Adeptus Mechanicus",
    "grey-knights":         "Grey Knights",
    "adepta-sororitas":     "Adepta Sororitas",
    "imperial-knights":     "Imperial Knights",
    "chaos-knights":        "Chaos Knights",
    "leagues-of-votann":    "Leagues of Votann",
    "adeptus-custodes":     "Adeptus Custodes",
    "chaos-daemons":        "Chaos Daemons",
    "imperial-agents":      "Imperial Agents",
}

BASE_URL = "https://wahapedia.ru/wh40k10ed/factions/{slug}/datasheets.html"
OUTPUT_DIR = Path("./output")
HEADERS = {
    "User-Agent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/124.0.0 Safari/537.36",
    "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8",
}

# ── Parsing ───────────────────────────────────────────────────────────────────

def clean(text):
    return re.sub(r"\s+", " ", text).strip()

def parse_stat_block(ds):
    stats = {}
    for wrap in ds.find_all("div", class_="dsCharWrap"):
        name_div  = wrap.find("div", class_="dsCharName")
        value_div = wrap.find("div", class_="dsCharValue")
        if name_div and value_div:
            label = clean(name_div.get_text())
            value = clean(value_div.get_text())
            if label:
                stats[label] = value
    return stats

def parse_weapons(ds):
    weapons = []
    for table in ds.find_all("table", class_="wTable"):
        rows = table.find_all("tr")
        for row in rows:
            cells = [clean(td.get_text()) for td in row.find_all("td")]
            cells = [c for c in cells if c]  # drop empty
            if len(cells) >= 6 and cells[0] not in ("", "MELEE WEAPONS", "RANGED WEAPONS"):
                weapons.append({
                    "name":      cells[0],
                    "range":     cells[1],
                    "A":         cells[2],
                    "BS_WS":     cells[3],
                    "S":         cells[4],
                    "AP":        cells[5],
                    "D":         cells[6] if len(cells) > 6 else "",
                    "abilities": cells[7] if len(cells) > 7 else "",
                })
    return weapons

def parse_abilities(ds):
    abilities = []
    right_col = ds.find("div", class_=lambda c: c and "dsRightСol" in c)
    if not right_col:
        return abilities
    for ab in right_col.find_all("div", class_="dsAbility"):
        b_tag = ab.find("b")
        if b_tag and b_tag.get_text().strip().endswith(":"):
            name = clean(b_tag.get_text()).rstrip(":")
            b_tag.decompose()
            desc = clean(ab.get_text())
            abilities.append({"name": name, "description": desc})
    return abilities

def parse_keywords(ds):
    kw_div = ds.find("div", class_="ds2colKW")
    if not kw_div:
        return []
    return [clean(span.get_text()) for span in kw_div.find_all("span", class_="kwb")]


def parse_datasheet(ds):
    name_tag = ds.find("div", class_="dsH2Header")
    name = clean(name_tag.find("div").get_text()) if name_tag else "Unknown"
    return {
        "name":      name,
        "stats":     parse_stat_block(ds),
        "weapons":   parse_weapons(ds),
        "abilities": parse_abilities(ds),
        "keywords":  parse_keywords(ds),
    }
# ── Async fetch + parse ───────────────────────────────────────────────────────

async def fetch(session, slug, name, retries=3):
    url = BASE_URL.format(slug=slug)
    for attempt in range(retries):
        try:
            async with session.get(url, headers=HEADERS) as r:
                status = r.status
                html = await r.text() if status == 200 else ""
            print(f"[→] {name} ({status})")
            return slug, name, status, html
        except Exception as e:
            print(f"[!] {name} attempt {attempt+1} failed: {e}")
            await asyncio.sleep(2 ** attempt)  # 1s, 2s, 4s backoff
    print(f"[✗] {name} giving up")
    return slug, name, 0, ""
    
async def scrape_all():
    OUTPUT_DIR.mkdir(exist_ok=True)
    async with aiohttp.ClientSession(connector=aiohttp.TCPConnector(limit=3)) as session:
        results = await asyncio.gather(*[fetch(session, s, n) for s, n in FACTIONS.items()])

    for slug, name, status, html in results:
        if status != 200:
            print(f"[✗] {name} skipped ({status})")
            continue
        soup = BeautifulSoup(html, "lxml")
        datasheets = soup.find_all("div", class_=re.compile(r"\bdatasheet\b", re.I))
        units = [parse_datasheet(ds) for ds in datasheets]
        out = OUTPUT_DIR / f"{slug}.json"
        out.write_text(json.dumps(units, indent=2, ensure_ascii=False))
        print(f"[✓] {name}: {len(units)} units → {out}")

asyncio.run(scrape_all())
# Out:
# ---------------------------------------------------------------------------
# TransferEncodingError                     Traceback (most recent call last)
# File ~/.pyenv/versions/3.12.9/lib/python3.12/site-packages/aiohttp/client_proto.py:144, in ResponseHandler.connection_lost(self, exc)
#     143 try:
# --> 144     uncompleted = self._parser.feed_eof()
#     145 except Exception as underlying_exc:
#
# File ~/.pyenv/versions/3.12.9/lib/python3.12/site-packages/aiohttp/_http_parser.pyx:543, in aiohttp._http_parser.HttpParser.feed_eof()
#
# TransferEncodingError: 400, message:
#   Not enough data to satisfy transfer length header.
#
# The above exception was the direct cause of the following exception:
#
# ClientPayloadError                        Traceback (most recent call last)
# Cell In[4], line 133
#     130         out.write_text(json.dumps(units, indent=2, ensure_ascii=False))
#     131         print(f"[✓] {name}: {len(units)} units → {out}")
# --> 133 asyncio.run(scrape_all())
#
# File ~/.pyenv/versions/3.12.9/lib/python3.12/site-packages/nest_asyncio.py:30, in _patch_asyncio.<locals>.run(main, debug)
#      28 task = asyncio.ensure_future(main)
#      29 try:
# ---> 30     return loop.run_until_complete(task)
#      31 finally:
#      32     if not task.done():
#
# File ~/.pyenv/versions/3.12.9/lib/python3.12/site-packages/nest_asyncio.py:98, in _patch_loop.<locals>.run_until_complete(self, future)
#      95 if not f.done():
#      96     raise RuntimeError(
#      97         'Event loop stopped before Future completed.')
# ---> 98 return f.result()
#
# File ~/.pyenv/versions/3.12.9/lib/python3.12/asyncio/futures.py:202, in Future.result(self)
#     200 self.__log_traceback = False
#     201 if self._exception is not None:
# --> 202     raise self._exception.with_traceback(self._exception_tb)
#     203 return self._result
#
# File ~/.pyenv/versions/3.12.9/lib/python3.12/asyncio/tasks.py:314, in Task.__step_run_and_handle_result(***failed resolving arguments***)
#     310 try:
#     311     if exc is None:
#     312         # We use the `send` method directly, because coroutines
#     313         # don't have `__iter__` and `__next__` methods.
# --> 314         result = coro.send(None)
#     315     else:
#     316         result = coro.throw(exc)
#
# Cell In[4], line 120, in scrape_all()
#     118 OUTPUT_DIR.mkdir(exist_ok=True)
#     119 async with aiohttp.ClientSession(connector=aiohttp.TCPConnector(limit=5)) as session:
# --> 120     results = await asyncio.gather(*[fetch(session, s, n) for s, n in FACTIONS.items()])
#     122 for slug, name, status, html in results:
#     123     if status != 200:
#
# File ~/.pyenv/versions/3.12.9/lib/python3.12/asyncio/tasks.py:385, in Task.__wakeup(self, future)
#     383 def __wakeup(self, future):
#     384     try:
# --> 385         future.result()
#     386     except BaseException as exc:
#     387         # This may also be a cancellation.
#     388         self.__step(exc)
#
# File ~/.pyenv/versions/3.12.9/lib/python3.12/asyncio/tasks.py:316, in Task.__step_run_and_handle_result(***failed resolving arguments***)
#     314         result = coro.send(None)
#     315     else:
# --> 316         result = coro.throw(exc)
#     317 except StopIteration as exc:
#     318     if self._must_cancel:
#     319         # Task is cancelled right before coro stops.
#
# Cell In[4], line 114, in fetch(session, slug, name)
#     112 async with session.get(url, headers=HEADERS) as r:
#     113     status = r.status
# --> 114     html = await r.text() if status == 200 else ""
#     115 return slug, name, status, html
#
# File ~/.pyenv/versions/3.12.9/lib/python3.12/site-packages/aiohttp/client_reqrep.py:735, in ClientResponse.text(self, encoding, errors)
#     733 """Read response payload and decode."""
#     734 if self._body is None:
# --> 735     await self.read()
#     737 if encoding is None:
#     738     encoding = self.get_encoding()
#
# File ~/.pyenv/versions/3.12.9/lib/python3.12/site-packages/aiohttp/client_reqrep.py:693, in ClientResponse.read(self)
#     691 if self._body is None:
#     692     try:
# --> 693         self._body = await self.content.read()
#     694         for trace in self._traces:
#     695             await trace.send_response_chunk_received(
#     696                 self.method, self.url, self._body
#     697             )
#
# File ~/.pyenv/versions/3.12.9/lib/python3.12/site-packages/aiohttp/streams.py:446, in StreamReader.read(self, n)
#     444 blocks = []
#     445 while True:
# --> 446     block = await self.readany()
#     447     if not block:
#     448         break
#
# File ~/.pyenv/versions/3.12.9/lib/python3.12/site-packages/aiohttp/streams.py:468, in StreamReader.readany(self)
#     464 # TODO: should be `if` instead of `while`
#     465 # because waiter maybe triggered on chunk end,
#     466 # without feeding any data
#     467 while not self._buffer and not self._eof:
# --> 468     await self._wait("readany")
#     470 return self._read_nowait(-1)
#
# File ~/.pyenv/versions/3.12.9/lib/python3.12/site-packages/aiohttp/streams.py:372, in StreamReader._wait(self, func_name)
#     370 try:
#     371     with self._timer:
# --> 372         await waiter
#     373 finally:
#     374     self._waiter = None
#
# File ~/.pyenv/versions/3.12.9/lib/python3.12/asyncio/futures.py:289, in Future.__await__(self)
#     287 if not self.done():
#     288     self._asyncio_future_blocking = True
# --> 289     yield self  # This tells Task to wait for completion.
#     290 if not self.done():
#     291     raise RuntimeError("await wasn't used with future")
#
# File ~/.pyenv/versions/3.12.9/lib/python3.12/asyncio/tasks.py:385, in Task.__wakeup(self, future)
#     383 def __wakeup(self, future):
#     384     try:
# --> 385         future.result()
#     386     except BaseException as exc:
#     387         # This may also be a cancellation.
#     388         self.__step(exc)
#
# File ~/.pyenv/versions/3.12.9/lib/python3.12/asyncio/futures.py:202, in Future.result(self)
#     200 self.__log_traceback = False
#     201 if self._exception is not None:
# --> 202     raise self._exception.with_traceback(self._exception_tb)
#     203 return self._result
#
# ClientPayloadError: Response payload is not completed: <TransferEncodingError: 400, message='Not enough data to satisfy transfer length header.'>
